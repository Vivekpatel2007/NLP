# %% [markdown]
# **U24AI040 NLP LAB-4**

# %% [markdown]
# Q1. Take the data you tokenized (your language data) in Assignment-1 and build 4 language model as the following:
#
# a. Unigram Model
#
# b. Bigram Model
#
# c. Trigram Model
#
# d. Quadrigram Model
#
# Take at least 1000000 sentences and split them into training, development, and test sets. Development and test sets have 1000 sentences each, and training data contains rest of the sentences.

# %%
import math
from collections import Counter, defaultdict
from pathlib import Path

import pandas as pd

# %%
DATA_PATH = Path(
    r"C:/Users/VIVEK/Desktop/NLP Lab/ASSIGNMENT_1/Q1/tokenized_gujarati_corpus/10lakh sentence.parquet"
)

df = pd.read_parquet(DATA_PATH, columns=["tokens"])

print("Total sentences:", len(df))
# Out:
# Total sentences: 1099721

# %%
print(df.head())
print(df["tokens"].iloc[0])
print("Tokens in first sentence:", len(df["tokens"].iloc[0]))
# Out:
#                                               tokens
# 0  [આ, વીડિયો, જુઓ, :, ઊંઝા, માર્કેટયાર્ડ, આજથી, ...
# 1                       [મિથેનોલ, આવ્યો, ક્યાંથી, ?]
# 2  [આખરે, ત્રણ, રાજ્યોમાં, મળેલ, હાર, પર, કોંગ્રે...
# 3  [તેમણે, કહ્યું, કે, ,, ત્રિપુરા, ,, નાગાલેન્ડ,...
# 4  [આ, આંકડો, માટે, ,, અને, વજન, ઘટાડવા, માટે, પ્...
# ['આ' 'વીડિયો' 'જુઓ' ':' 'ઊંઝા' 'માર્કેટયાર્ડ' 'આજથી' '25' 'જુલાઈ' 'સુધી'
#  'બંધ']
# Tokens in first sentence: 11

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

dev_df = df.iloc[:1000]
test_df = df.iloc[1000:2000]
train_df = df.iloc[2000:]

print("Training sentences:", len(train_df))
print("Development sentences:", len(dev_df))
print("Test sentences:", len(test_df))
# Out:
# Training sentences: 1097721
# Development sentences: 1000
# Test sentences: 1000

# %%
def most_common(counter):
    
    if not counter:
        return None
    
    return counter.most_common(1)[0][0]

# %%
def train_model(sentences):

    unigram = Counter()
    bigram = defaultdict(Counter)
    trigram = defaultdict(Counter)
    quadrigram = defaultdict(Counter)

    for tokens in sentences:
        tokens = list(tokens)

        for word in tokens:

            unigram[word] += 1

        unigram["</s>"] += 1

        #Biagram counts
        tokens2 = (
            ["<s>"]
            + tokens
            + ["</s>"]
        )

        for i in range(len(tokens2) - 1):

            w1 = tokens2[i]
            w2 = tokens2[i + 1]

            bigram[w1][w2] += 1

        # Trigram counts
        tokens3 = ["<s>", "<s>"] + tokens + ["</s>"]

        for i in range(len(tokens3) - 2):

            w1=tokens3[i]
            w2=tokens3[i+1]
            w3=tokens3[i+2]
            trigram[(w1, w2)][w3] += 1

        # Quadrigram counts
        tokens4 = ["<s>", "<s>", "<s>"] + tokens + ["</s>"]

        for i in range(len(tokens4) - 3):

            w1=tokens4[i]
            w2=tokens4[i+1]
            w3=tokens4[i+2]
            w4=tokens4[i+3]
            quadrigram[(w1, w2, w3)][w4] += 1


    return unigram, bigram, trigram, quadrigram

# %%
unigram, bigram, trigram, quadrigram = train_model(
    train_df["tokens"]
)

print("All models trained successfully.")
# Out:
# All models trained successfully.

# %%
print("Top 20 most frequent words:\n")

for word, count in unigram.most_common(20):

    print(
        word,
        "->",
        count
    )
# Out:
# Top 20 most frequent words:
#
# </s> -> 1097721
# . -> 946503
# છે -> 610887
# , -> 448074
# અને -> 277336
# આ -> 179705
# કે -> 158481
# પણ -> 125744
# માટે -> 125617
# - -> 101993
# એક -> 94749
# કરી -> 93775
# પર -> 92218
# તે -> 82049
# જ -> 81064
# સાથે -> 80871
# હતી -> 79548
# તો -> 59450
# હતો -> 56879
# હતા -> 51945

# %%
for context, words in list(bigram.items())[:10]:

    print(
        context,
        "->",
        words.most_common(5)
    )
# Out:
# <s> -> [('આ', 75538), ('.', 30378), ('જો', 15244), ('તે', 14329), ('પરંતુ', 10548)]
# ૮૦ -> [('ટકા', 94), (',', 54), ('થી', 26), ('%', 19), (')', 19)]
# થી -> [('વધુ', 2574), ('વધારે', 532), ('૬', 292), ('પણ', 214), ('12', 207)]
# ૧૦૦ -> [('ટકા', 169), ('થી', 143), ('જેટલા', 43), ('%', 34), ('કરોડ', 32)]
# ના -> [('રોજ', 3229), ('પાડી', 451), ('હોય', 317), ('કારણે', 284), ('દિવસે', 273)]
# ડઝન -> [('જેટલા', 34), ('જેટલી', 10), ('કરતા', 7), ('લોકો', 4), ('વર્ષ', 4)]
# મળતા -> [('જ', 128), ('નથી', 109), ('હતા', 96), ('હોય', 81), ('આ', 37)]
# હતા -> [('.', 36925), ('અને', 3775), (',', 3170), ('ત્યારે', 959), ('કે', 841)]
# એ -> [('છે', 3762), ('.', 1762), ('જ', 1719), ('પણ', 1383), ('માટે', 637)]
# હોલસેલ -> [('માર્કેટમાં', 6), ('વેપારી', 6), ('વેપારીઓ', 5), (',', 4), ('પ્રાઇઝ', 3)]

# %%
for context, words in list(trigram.items())[:10]:

    print(
        context,
        "->",
        words.most_common(5)
    )
# Out:
# ('<s>', '<s>') -> [('આ', 75538), ('.', 30378), ('જો', 15244), ('તે', 14329), ('પરંતુ', 10548)]
# ('<s>', '૮૦') -> [(')', 16), ('ટકા', 7), (',', 5), ('ના', 4), ('હજાર', 4)]
# ('૮૦', 'થી') -> [('વધુ', 10), ('૧૦૦', 4), ('૮૫', 4), ('૯૦', 4), ('૧૫૦', 1)]
# ('થી', '૧૦૦') -> [('ટકા', 8), ('ના', 2), ('મી', 2), ('વય', 2), (',', 1)]
# ('૧૦૦', 'ના') -> [('કિલો', 4), ('સ્ટેમ્પ', 2), ('ડઝન', 1), ('કિલોનો', 1), ('ખાનામાં', 1)]
# ('ના', 'ડઝન') -> [('મળતા', 1)]
# ('ડઝન', 'મળતા') -> [('હતા', 1)]
# ('મળતા', 'હતા') -> [('.', 56), (',', 13), ('પરંતુ', 4), ('અને', 4), ('એ', 2)]
# ('હતા', 'એ') -> [('જ', 13), ('સમયે', 10), ('વખતે', 7), ('દરમ્યાન', 4), ('દરમિયાન', 4)]
# ('એ', 'હોલસેલ') -> [('માર્કેટમાં', 1)]

# %%
for context, words in list(quadrigram.items())[:10]:

    print(
        context,
        "->",
        words.most_common(5)
    )
# Out:
# ('<s>', '<s>', '<s>') -> [('આ', 75538), ('.', 30378), ('જો', 15244), ('તે', 14329), ('પરંતુ', 10548)]
# ('<s>', '<s>', '૮૦') -> [(')', 16), ('ટકા', 7), (',', 5), ('ના', 4), ('હજાર', 4)]
# ('<s>', '૮૦', 'થી') -> [('૧૦૦', 1), ('વધુ', 1)]
# ('૮૦', 'થી', '૧૦૦') -> [('ના', 2), ('મીટર', 1), ('ફુટ', 1)]
# ('થી', '૧૦૦', 'ના') -> [('ડઝન', 1), ('કિલો', 1)]
# ('૧૦૦', 'ના', 'ડઝન') -> [('મળતા', 1)]
# ('ના', 'ડઝન', 'મળતા') -> [('હતા', 1)]
# ('ડઝન', 'મળતા', 'હતા') -> [('એ', 1)]
# ('મળતા', 'હતા', 'એ') -> [('હોલસેલ', 1), ('વિસ્તાર', 1)]
# ('હતા', 'એ', 'હોલસેલ') -> [('માર્કેટમાં', 1)]

# %%
def unigram_probability(word, unigram):

    count = unigram.get(word, 0)

    total_words = sum(
        unigram.values()
    )

    if count == 0:
        return 0

    return count / total_words

# %%
def bigram_probability(previous_word,current_word,bigram):

    words = bigram.get(
        previous_word
    )

    if words is None:
        return 0

    count = words.get(
        current_word,
        0
    )

    total = sum(
        words.values()
    )

    if total == 0:
        return 0

    return count / total

# %%
def trigram_probability(previous_word1, previous_word2,current_word,trigram):

    context = (
        previous_word1,
        previous_word2
    )

    words = trigram.get(
        context
    )

    if words is None:
        return 0

    count = words.get(
        current_word,
        0
    )

    total = sum(
        words.values()
    )

    if total == 0:
        return 0

    return count / total

# %%
def quadrigram_probability(previous_word1,previous_word2,previous_word3,current_word,quadrigram):

    context = (
        previous_word1,
        previous_word2,
        previous_word3
    )

    words = quadrigram.get(
        context
    )

    if words is None:
        return 0

    count = words.get(
        current_word,
        0
    )

    total = sum(
        words.values()
    )

    if total == 0:
        return 0

    return count / total

# %%
def predict_bigram(
    previous_word,
    bigram
):

    words = bigram.get(
        previous_word
    )

    return most_common(words)

# %%
def predict_trigram(
    previous_word1,
    previous_word2,
    trigram
):

    words = trigram.get(
        (
            previous_word1,
            previous_word2
        )
    )

    return most_common(words)

# %%
def predict_quadrigram(
    previous_word1,
    previous_word2,
    previous_word3,
    quadrigram
):

    words = quadrigram.get(
        (
            previous_word1,
            previous_word2,
            previous_word3
        )
    )

    return most_common(words)

# %%
context = "ગુજરાતી"

prediction = predict_bigram(
    context,
    bigram
)

print(
    "Previous word:",
    context
)

print(
    "Predicted next word:",
    prediction
)
# Out:
# Previous word: ગુજરાતી
# Predicted next word: ફિલ્મ

# %% [markdown]
# prediction

# %%
word1 = "મને"
word2 = "ગુજરાતી"

prediction = predict_trigram(
    word1,
    word2,
    trigram
)

print(
    "Previous words:",
    word1,
    word2
)

print(
    "Predicted next word:",
    prediction
)
# Out:
# Previous words: મને ગુજરાતી
# Predicted next word: વાનગીઓ

# %%
word1 = "મને"
word2 = "ગુજરાતી"
word3 = "ભાષા"

prediction = predict_quadrigram(
    word1,
    word2,
    word3,
    quadrigram
)

print(
    "Previous words:",
    word1,
    word2,
    word3
)

print(
    "Predicted next word:",
    prediction
)
# Out:
# Previous words: મને ગુજરાતી ભાષા
# Predicted next word: None

# %%
def accuracy(
    sentences,
    order,
    bigram,
    trigram,
    quadrigram
):

    correct = 0
    total = 0


    for tokens in sentences:

        tokens = list(tokens)

        # biagram

        if order == 2:

            for i in range(
                len(tokens) - 1
            ):

                previous_word = tokens[i]

                actual_word = tokens[i + 1]

                predicted_word = predict_bigram(
                    previous_word,
                    bigram
                )

                if predicted_word == actual_word:

                    correct += 1

                total += 1

        # Trigram

        elif order == 3:

            for i in range(
                len(tokens) - 2
            ):

                previous_word1 = tokens[i]

                previous_word2 = tokens[i + 1]

                actual_word = tokens[i + 2]

                predicted_word = predict_trigram(
                    previous_word1,
                    previous_word2,
                    trigram
                )

                if predicted_word == actual_word:

                    correct += 1

                total += 1

        # Quadrigram

        elif order == 4:

            for i in range(
                len(tokens) - 3
            ):

                previous_word1 = tokens[i]

                previous_word2 = tokens[i + 1]

                previous_word3 = tokens[i + 2]

                actual_word = tokens[i + 3]

                predicted_word = predict_quadrigram(
                    previous_word1,
                    previous_word2,
                    previous_word3,
                    quadrigram
                )

                if predicted_word == actual_word:

                    correct += 1

                total += 1


    if total == 0:

        return 0

    return correct / total

# %%
bigram_dev_accuracy = accuracy(
    dev_df["tokens"],
    2,
    bigram,
    trigram,
    quadrigram
)

trigram_dev_accuracy = accuracy(
    dev_df["tokens"],
    3,
    bigram,
    trigram,
    quadrigram
)

quadrigram_dev_accuracy = accuracy(
    dev_df["tokens"],
    4,
    bigram,
    trigram,
    quadrigram
)


print(
    "Bigram Development Accuracy:",
    bigram_dev_accuracy #quadrigram_dev_accuracy
)

print(
    "Trigram Development Accuracy:",
    trigram_dev_accuracy
)

print(
    "Quadrigram Development Accuracy:",
    quadrigram_dev_accuracy #bigram_dev_accuracy
)
# Out:
# Bigram Development Accuracy: 0.178442160127407
# Trigram Development Accuracy: 0.1772723732377911
# Quadrigram Development Accuracy: 0.10971207924116512

# %%
bigram_test_accuracy = accuracy(
    test_df["tokens"],2,bigram,trigram,quadrigram)

trigram_test_accuracy = accuracy(
    test_df["tokens"],
    3,
    bigram,
    trigram,
    quadrigram
)

quadrigram_test_accuracy = accuracy(
    test_df["tokens"],
    4,
    bigram,
    trigram,
    quadrigram
)


print(
    "Bigram Test Accuracy:",
    bigram_test_accuracy    #quadrigram_test_accuracy
)

print(
    "Trigram Test Accuracy:",
    trigram_test_accuracy
)

print(
    "Quadrigram Test Accuracy:",
    quadrigram_test_accuracy #bigram_test_accuracy
)
# Out:
# Bigram Test Accuracy: 0.17667638483965015
# Trigram Test Accuracy: 0.1729517836142689
# Quadrigram Test Accuracy: 0.10777683854606931

# %%
print(
    f"Bigram Test Accuracy: "
    f"{bigram_test_accuracy * 100:.2f}%"
)

print(
    f"Trigram Test Accuracy: "
    f"{trigram_test_accuracy * 100:.2f}%"
)

print(
    f"Quadrigram Test Accuracy: "
    f"{quadrigram_test_accuracy * 100:.2f}%"
)


print(
    f"Bigram Test Accuracy: "
    f"{quadrigram_test_accuracy * 100:.2f}%"
)

print(
    f"Trigram Test Accuracy: "
    f"{trigram_test_accuracy * 100:.2f}%"
)

print(
    f"Quadrigram Test Accuracy: "
    f"{bigram_test_accuracy * 100:.2f}%"
)
# Out:
# Bigram Test Accuracy: 17.67%
# Trigram Test Accuracy: 17.30%
# Quadrigram Test Accuracy: 10.78%

# %%
def get_ngrams(
    tokens,
    n
):

    tokens = (
        ["<s>"] * (n - 1)
        + list(tokens)
        + ["</s>"]
    )

    ngrams = []


    for i in range(
        len(tokens) - n + 1
    ):

        current_ngram = []


        for j in range(n):

            current_ngram.append(
                tokens[i + j]
            )


        ngrams.append(
            current_ngram
        )


    return ngrams

# %%
sentence = [
    "મને",
    "ગુજરાતી",
    "આવે"
]

print(
    get_ngrams(sentence, 2)
)
# Out:
# [['<s>', 'મને'], ['મને', 'ગુજરાતી'], ['ગુજરાતી', 'આવે'], ['આવે', '</s>']]

# %%
def perplexity(
    sentences,
    order,
    unigram,
    bigram,
    trigram,
    quadrigram
):

    log_probability = 0

    total = 0

    total_unigrams = sum(
        unigram.values()
    )


    bigram_totals = {}

    for context in bigram:

        bigram_totals[context] = sum(
            bigram[context].values()
        )



    trigram_totals = {}

    for context in trigram:

        trigram_totals[context] = sum(
            trigram[context].values()
        )


    quadrigram_totals = {}

    for context in quadrigram:

        quadrigram_totals[context] = sum(
            quadrigram[context].values()
        )


    for tokens in sentences:

        ngrams = get_ngrams(
            tokens,
            order
        )


        for ngram in ngrams:

            word = ngram[-1]

            # Unigram

            if order == 1:

                count = unigram.get(
                    word,
                    0
                )


                if count == 0:

                    return float("inf")


                probability = (
                    count /
                    total_unigrams
                )
            # Bigram

            elif order == 2:

                context = ngram[0]


                counts = bigram.get(
                    context
                )


                if counts is None:

                    return float("inf")


                count = counts.get(
                    word,
                    0
                )


                if count == 0:

                    return float("inf")


                probability = (
                    count /
                    bigram_totals[context]
                )

            # Trigram

            elif order == 3:

                context = (
                    ngram[0],
                    ngram[1]
                )


                counts = trigram.get(
                    context
                )


                if counts is None:

                    return float("inf")


                count = counts.get(
                    word,
                    0
                )


                if count == 0:

                    return float("inf")


                probability = (
                    count /
                    trigram_totals[context]
                )


            # quadrigram

            elif order == 4:

                context = (
                    ngram[0],
                    ngram[1],
                    ngram[2]
                )


                counts = quadrigram.get(
                    context
                )


                if counts is None:

                    return float("inf")


                count = counts.get(
                    word,
                    0
                )


                if count == 0:

                    return float("inf")


                probability = (
                    count /
                    quadrigram_totals[context]
                )


            log_probability += math.log(
                probability
            )

            total += 1



    if total == 0:

        return 0


    return math.exp(
        -log_probability / total
    )

# %%
unigram_dev_pp = perplexity(
    dev_df["tokens"],
    1,
    unigram,
    bigram,
    trigram,
    quadrigram
)


bigram_dev_pp = perplexity(
    dev_df["tokens"],
    2,
    unigram,
    bigram,
    trigram,
    quadrigram
)


trigram_dev_pp = perplexity(
    dev_df["tokens"],
    3,
    unigram,
    bigram,
    trigram,
    quadrigram
)


quadrigram_dev_pp = perplexity(
    dev_df["tokens"],
    4,
    unigram,
    bigram,
    trigram,
    quadrigram
)


print(
    "Unigram Development Perplexity:",
    unigram_dev_pp
)

print(
    "Bigram Development Perplexity:",
    bigram_dev_pp
)

print(
    "Trigram Development Perplexity:",
    trigram_dev_pp
)

print(
    "Quadrigram Development Perplexity:",
    quadrigram_dev_pp
)
# Out:
# Unigram Development Perplexity: inf
# Bigram Development Perplexity: inf
# Trigram Development Perplexity: inf
# Quadrigram Development Perplexity: inf

# %%
unigram_test_pp = perplexity(
    test_df["tokens"],
    1,
    unigram,
    bigram,
    trigram,
    quadrigram
)


bigram_test_pp = perplexity(
    test_df["tokens"],
    2,
    unigram,
    bigram,
    trigram,
    quadrigram
)


trigram_test_pp = perplexity(
    test_df["tokens"],
    3,
    unigram,
    bigram,
    trigram,
    quadrigram
)


quadrigram_test_pp = perplexity(
    test_df["tokens"],
    4,
    unigram,
    bigram,
    trigram,
    quadrigram
)


print(
    "Unigram Test Perplexity:",
    unigram_test_pp
)

print(
    "Bigram Test Perplexity:",
    bigram_test_pp
)

print(
    "Trigram Test Perplexity:",
    trigram_test_pp
)

print(
    "Quadrigram Test Perplexity:",
    quadrigram_test_pp
)
# Out:
# Unigram Test Perplexity: inf
# Bigram Test Perplexity: inf
# Trigram Test Perplexity: inf
# Quadrigram Test Perplexity: inf

# %%
results = pd.DataFrame({

    "Model": [
        "Unigram",
        "Bigram",
        "Trigram",
        "Quadrigram"
    ],

    "Development Perplexity": [
        unigram_dev_pp,
        bigram_dev_pp,
        trigram_dev_pp,
        quadrigram_dev_pp
    ],

    "Test Perplexity": [
        unigram_test_pp,
        bigram_test_pp,
        trigram_test_pp,
        quadrigram_test_pp
    ],

    "Development Accuracy": [
        None,
        bigram_dev_accuracy,
        trigram_dev_accuracy,
        quadrigram_dev_accuracy
    ],

    "Test Accuracy": [
        None,
        bigram_test_accuracy,
        trigram_test_accuracy,
        quadrigram_test_accuracy
    ]
})

results
# Out:
#         Model  Development Perplexity  Test Perplexity  Development Accuracy  \
# 0     Unigram                     inf              inf                   NaN
# 1      Bigram                     inf              inf              0.178442
# 2     Trigram                     inf              inf              0.177272
# 3  Quadrigram                     inf              inf              0.109712
#
#    Test Accuracy
# 0            NaN
# 1       0.176676
# 2       0.172952
# 3       0.107777

# %%
accuracy_results = pd.DataFrame({

    "Model": [
        "Bigram",
        "Trigram",
        "Quadrigram"
    ],

    "Development Accuracy (%)": [
        bigram_dev_accuracy * 100,
        trigram_dev_accuracy * 100,
        quadrigram_dev_accuracy * 100
    ],

    "Test Accuracy (%)": [
        bigram_test_accuracy * 100,
        trigram_test_accuracy * 100,
        quadrigram_test_accuracy * 100
    ]
})

accuracy_results
# Out:
#         Model  Development Accuracy (%)  Test Accuracy (%)
# 0      Bigram                 17.844216          17.667638
# 1     Trigram                 17.727237          17.295178
# 2  Quadrigram                 10.971208          10.777684

# %%
def show_bigram_prediction(
    word,
    bigram
):

    prediction = predict_bigram(
        word,
        bigram
    )

    print(
        "Input word:",
        word
    )

    print(
        "Predicted next word:",
        prediction
    )

# %%
show_bigram_prediction(
    "ગુજરાતી",
    bigram
)
# Out:
# Input word: ગુજરાતી
# Predicted next word: ફિલ્મ

# %%
def show_trigram_prediction(
    word1,
    word2,
    trigram
):

    prediction = predict_trigram(
        word1,
        word2,
        trigram
    )

    print(
        "Input:",
        word1,
        word2
    )

    print(
        "Predicted next word:",
        prediction
    )

# %%
show_trigram_prediction(
    "મને",
    "ગુજરાતી",
    trigram
)
# Out:
# Input: મને ગુજરાતી
# Predicted next word: વાનગીઓ

# %%
def show_quadrigram_prediction(
    word1,
    word2,
    word3,
    quadrigram
):

    prediction = predict_quadrigram(
        word1,
        word2,
        word3,
        quadrigram
    )

    print(
        "Input:",
        word1,
        word2,
        word3
    )

    print(
        "Predicted next word:",
        prediction
    )

# %%
show_quadrigram_prediction(
    "મને",
    "ગુજરાતી",
    "ભાષા",
    quadrigram
)
# Out:
# Input: મને ગુજરાતી ભાષા
# Predicted next word: None
